# %%
import pandas as pd
from pathlib import Path
import os

# %%
PROJECT_DIR = Path.cwd().parent

DATA_FOLDER = PROJECT_DIR / "Extracted_Data"

OUTPUT_FOLDER = PROJECT_DIR / "processed"

OUTPUT_FOLDER.mkdir(exist_ok=True)

# %%
excel_files = list(DATA_FOLDER.rglob("*.xlsx"))

print("Total Excel Files :", len(excel_files))
# Out:
# Total Excel Files : 24

# %%
excel_files = list(DATA_FOLDER.rglob("*.xlsx"))

print("Total Excel Files :", len(excel_files))
# Out:
# Total Excel Files : 24

# %%
sample = excel_files[0]

print(sample)

df = pd.read_excel(sample)

df.head()
# Out:
# c:\Users\vikhy\Desktop\Nikitha project\Extracted_Data\DZwEI 30.09-07.10\DZwEI 30.09-07.10\Friedberger Tor\2024-09-30_to_2024-10-07_UI_202403B0924.xlsx
#   Name der Erhebung Unnamed: 1  \
# 0    Geräte-UUID(s)        NaN
# 1         Zähldatum        NaN
# 2         Startzeit        NaN
# 3          Standort        NaN
# 4        Gesamt-Kfz        NaN
#
#                                       UI_202403B0924 Unnamed: 3 Unnamed: 4  \
# 0               9a97153e-ff0d-4897-ba03-5c483d07634d        NaN        NaN
# 1                                  Mon, 30. Sep 2024        NaN        NaN
# 2                                              00:00        NaN        NaN
# 3                                     (50.118,8.688)        NaN        NaN
# 4  Pkw, Pkw mit Anhänger, Kraftrad, Lieferwagen, ...        NaN        NaN
#
#    Unnamed: 5  Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9  ...  Unnamed: 13  \
# 0         NaN         NaN        NaN        NaN         NaN  ...          NaN
# ...

# %%
df.head()
# Out:
#   Name der Erhebung Unnamed: 1  \
# 0    Geräte-UUID(s)        NaN
# 1         Zähldatum        NaN
# 2         Startzeit        NaN
# 3          Standort        NaN
# 4        Gesamt-Kfz        NaN
#
#                                       UI_202403B0924 Unnamed: 3 Unnamed: 4  \
# 0               9a97153e-ff0d-4897-ba03-5c483d07634d        NaN        NaN
# 1                                  Mon, 30. Sep 2024        NaN        NaN
# 2                                              00:00        NaN        NaN
# 3                                     (50.118,8.688)        NaN        NaN
# 4  Pkw, Pkw mit Anhänger, Kraftrad, Lieferwagen, ...        NaN        NaN
#
#    Unnamed: 5  Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9  ...  Unnamed: 13  \
# 0         NaN         NaN        NaN        NaN         NaN  ...          NaN
# 1         NaN         NaN        NaN        NaN         NaN  ...          NaN
# 2         NaN         NaN        NaN        NaN         NaN  ...          NaN
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Name der Erhebung', 'Unnamed: 1', 'UI_202403B0924', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22']

# %%
import pandas as pd

sample = excel_files[0]

# Read the first 40 rows without assuming a header
df = pd.read_excel(sample, header=None)

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

display(df.head(40))
# Out:
#                    0                            1   \
# 0   Name der Erhebung                          NaN
# 1      Geräte-UUID(s)                          NaN
# 2           Zähldatum                          NaN
# 3           Startzeit                          NaN
# 4            Standort                          NaN
# 5          Gesamt-Kfz                          NaN
# 6                 NaN                          NaN
# 7                 NaN                          NaN
# 8                 NaN                          NaN
# 9                 NaN                   von Rechts
# 10                NaN                          NaN
# 11          Startzeit  von Rechts Links nach Unten
# 12           00:00:00                            5
# 13           00:15:00                            4
# 14           00:30:00                            5
# 15           00:45:00                            4
# 16           01:00:00                            6
# ...

# %%
pd.read_excel(sample)
# Out:
#     Name der Erhebung                   Unnamed: 1  \
# 0      Geräte-UUID(s)                          NaN
# 1           Zähldatum                          NaN
# 2           Startzeit                          NaN
# 3            Standort                          NaN
# 4          Gesamt-Kfz                          NaN
# 5                 NaN                          NaN
# 6                 NaN                          NaN
# 7                 NaN                          NaN
# 8                 NaN                   von Rechts
# 9                 NaN                          NaN
# 10          Startzeit  von Rechts Links nach Unten
# 11           00:00:00                            5
# 12           00:15:00                            4
# 13           00:30:00                            5
# 14           00:45:00                            4
# 15           01:00:00                            6
# 16           01:15:00                            3
# ...

# %%
import pandas as pd

xls = pd.ExcelFile(sample)

print(xls.sheet_names)
# Out:
# ['Gesamt-Kfz', 'SV >3.5t', 'LV <3.5t', 'Pkw', 'Pkw mit Anhänger', 'Lkw', 'Lkw mit Anhänger', 'Bus', 'Lieferwagen', 'Kraftrad', 'Sattel-Kfz', 'Erklärungen']

# %%
df.iloc[:35].to_csv("first35rows.csv", index=False)
